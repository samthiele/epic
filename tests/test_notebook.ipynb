# %%
from epic import load_image, pick_single, pick_multi

# %%
image = load_image('stinkbug.jpg')
image2 = image[::-1, :, : ].copy()

# %%
P = pick_single( image, line=True, width=5,n=3, backend='nbAgg' )
# Out:
# <img src="data:image/png;base64,..." width="359.9999921972103">

# %%
for p in P:
    print(p)
# Out:
# (108.30658200732441, 36.367760271292894)
# (167.10609201140772, 122.60704161061511)
# (227.86558568229378, 49.10765410551096)

# %%
P1, P2 = pick_multi( image, image2, line=True, width=5, n=3, backend='nbAgg' )
# Out:
# <img src="data:image/png;base64,..." width="359.9999921972103">

# %%
for p1,p2 in zip(P1, P2):
    print (p1, ' -> ', p2 )
# Out:
# (109.04667765475935, 40.96738838737758)  ->  (136.1065215402754, 183.34379775424676)
# (156.92178606759543, 113.82081423299769)  ->  (140.26957444573944, 137.5502157941427)
# (221.44910610228757, 72.19028517835761)  ->  (213.12300029135955, 147.95784805780272)
